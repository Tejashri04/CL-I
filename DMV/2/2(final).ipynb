# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
api_key = 'ad393ce4425574c1b24442cd11244e87'

# %%
state = "West Bengal"
city = "kolkata"

# %%
lat = 18.5204
lon = 73.8567

# %%
api_url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"

# %%
res = requests.get(api_url)
weather_data = res.json()
weather_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1731423600,
#    'main': {'temp': 296.42,
#     'feels_like': 295.87,
#     'temp_min': 296.42,
#     'temp_max': 296.42,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 940,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 1.88, 'deg': 80, 'gust': 2.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-12 15:00:00'},
#   {'dt': 1731434400,
#    'main': {'temp': 295.78,
#     'feels_like': 295.22,
#     'temp_min': 294.5,
#     'temp_max': 295.78,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 940,
#     'humidity': 43,
#     'temp_kf': 1.28},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
# ...

# %%
weather_data['list'][0]['weather'][0]['description']
# Out:
# 'scattered clouds'

# %%
temperatures = [item['main']['temp'] for item in weather_data['list']]
temperatures
# Out:
# [296.42,
#  295.78,
#  294.23,
#  292.05,
#  295.41,
#  300.8,
#  303.19,
#  301.09,
#  297.79,
#  295.29,
#  294.21,
#  293.38,
#  296.46,
#  301.88,
#  304.24,
#  302.15,
#  300.33,
#  299.4,
#  298.26,
#  296.57,
#  298.88,
#  302.13,
#  303.71,
#  301.17,
#  299.34,
#  298.35,
#  297.41,
#  297.39,
#  297.86,
#  301.35,
#  303.15,
#  301.89,
#  299.79,
#  298.65,
#  298.63,
#  298.15,
#  298.7,
#  301.35,
#  302.97,
#  301.32]

# %%
timestamps = [pd.to_datetime(item['dt'], unit='s') for item in weather_data['list']]
timestamps
# Out:
# [Timestamp('2024-11-12 15:00:00'),
#  Timestamp('2024-11-12 18:00:00'),
#  Timestamp('2024-11-12 21:00:00'),
#  Timestamp('2024-11-13 00:00:00'),
#  Timestamp('2024-11-13 03:00:00'),
#  Timestamp('2024-11-13 06:00:00'),
#  Timestamp('2024-11-13 09:00:00'),
#  Timestamp('2024-11-13 12:00:00'),
#  Timestamp('2024-11-13 15:00:00'),
#  Timestamp('2024-11-13 18:00:00'),
#  Timestamp('2024-11-13 21:00:00'),
#  Timestamp('2024-11-14 00:00:00'),
#  Timestamp('2024-11-14 03:00:00'),
#  Timestamp('2024-11-14 06:00:00'),
#  Timestamp('2024-11-14 09:00:00'),
#  Timestamp('2024-11-14 12:00:00'),
#  Timestamp('2024-11-14 15:00:00'),
#  Timestamp('2024-11-14 18:00:00'),
#  Timestamp('2024-11-14 21:00:00'),
#  Timestamp('2024-11-15 00:00:00'),
#  Timestamp('2024-11-15 03:00:00'),
#  Timestamp('2024-11-15 06:00:00'),
#  Timestamp('2024-11-15 09:00:00'),
#  Timestamp('2024-11-15 12:00:00'),
#  Timestamp('2024-11-15 15:00:00'),
#  Timestamp('2024-11-15 18:00:00'),
#  Timestamp('2024-11-15 21:00:00'),
# ...

# %%
humidity = [item['main']['humidity'] for item in weather_data['list']]
humidity
# Out:
# [41,
#  43,
#  47,
#  55,
#  51,
#  38,
#  33,
#  39,
#  41,
#  48,
#  56,
#  63,
#  58,
#  51,
#  44,
#  49,
#  58,
#  60,
#  67,
#  76,
#  68,
#  55,
#  48,
#  59,
#  68,
#  72,
#  74,
#  72,
#  59,
#  49,
#  47,
#  55,
#  58,
#  55,
#  46,
#  44,
#  52,
#  43,
#  45,
#  55]

# %%
wind_speed = [item['wind']['speed'] for item in weather_data['list']]
wind_speed
# Out:
# [1.88,
#  1.35,
#  1.53,
#  2.04,
#  2.54,
#  4.02,
#  2.76,
#  1.61,
#  1.6,
#  1.56,
#  1.56,
#  2.15,
#  2.88,
#  4.63,
#  2.49,
#  2.79,
#  2.26,
#  1.69,
#  1.9,
#  2.61,
#  3.24,
#  3.77,
#  3.12,
#  0.5,
#  2.09,
#  1.71,
#  2.79,
#  0.56,
#  1.52,
#  2.79,
#  1.96,
#  0.62,
#  2.03,
#  2.03,
#  1.31,
#  0.65,
#  3.02,
#  5.86,
#  3.84,
#  1.73]

# %%
weather_description = [item['weather'][0]['description'] for item in weather_data['list']]
weather_description
# Out:
# ['scattered clouds',
#  'scattered clouds',
#  'scattered clouds',
#  'scattered clouds',
#  'scattered clouds',
#  'few clouds',
#  'clear sky',
#  'clear sky',
#  'few clouds',
#  'few clouds',
#  'scattered clouds',
#  'broken clouds',
#  'scattered clouds',
#  'scattered clouds',
#  'broken clouds',
#  'broken clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'light rain',
#  'light rain',
#  'light rain',
#  'light rain',
#  'light rain',
#  'light rain',
#  'light rain',
#  'overcast clouds',
#  'broken clouds',
#  'few clouds',
#  'scattered clouds',
#  'broken clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'overcast clouds',
#  'scattered clouds']

# %%
df = pd.DataFrame({
    'Timestamp' : timestamps,
    'Temperature' : temperatures,
    'Humidity' : humidity,
    'Wind Speed' : wind_speed,
    'Weather Description' : weather_description
})

# %%
df
# Out:
#              Timestamp  Temperature  Humidity  Wind Speed Weather Description
# 0  2024-11-12 15:00:00       296.42        41        1.88    scattered clouds
# 1  2024-11-12 18:00:00       295.78        43        1.35    scattered clouds
# 2  2024-11-12 21:00:00       294.23        47        1.53    scattered clouds
# 3  2024-11-13 00:00:00       292.05        55        2.04    scattered clouds
# 4  2024-11-13 03:00:00       295.41        51        2.54    scattered clouds
# 5  2024-11-13 06:00:00       300.80        38        4.02          few clouds
# 6  2024-11-13 09:00:00       303.19        33        2.76           clear sky
# 7  2024-11-13 12:00:00       301.09        39        1.61           clear sky
# 8  2024-11-13 15:00:00       297.79        41        1.60          few clouds
# 9  2024-11-13 18:00:00       295.29        48        1.56          few clouds
# 10 2024-11-13 21:00:00       294.21        56        1.56    scattered clouds
# ...

# %%
df.set_index('Timestamp', inplace=True)

# %%
df
# Out:
#                      Temperature  Humidity  Wind Speed Weather Description
# Timestamp
# 2024-11-12 15:00:00       296.42        41        1.88    scattered clouds
# 2024-11-12 18:00:00       295.78        43        1.35    scattered clouds
# 2024-11-12 21:00:00       294.23        47        1.53    scattered clouds
# 2024-11-13 00:00:00       292.05        55        2.04    scattered clouds
# 2024-11-13 03:00:00       295.41        51        2.54    scattered clouds
# 2024-11-13 06:00:00       300.80        38        4.02          few clouds
# 2024-11-13 09:00:00       303.19        33        2.76           clear sky
# 2024-11-13 12:00:00       301.09        39        1.61           clear sky
# 2024-11-13 15:00:00       297.79        41        1.60          few clouds
# 2024-11-13 18:00:00       295.29        48        1.56          few clouds
# 2024-11-13 21:00:00       294.21        56        1.56    scattered clouds
# ...

# %%
df['Temperature'].dtype
# Out:
# dtype('float64')

# %%
df['Temperature'] = df['Temperature'].apply(lambda x: x - 273.15)

# %%
df
# Out:
#                      Temperature  Humidity  Wind Speed Weather Description
# Timestamp
# 2024-11-12 15:00:00        23.27        41        1.88    scattered clouds
# 2024-11-12 18:00:00        22.63        43        1.35    scattered clouds
# 2024-11-12 21:00:00        21.08        47        1.53    scattered clouds
# 2024-11-13 00:00:00        18.90        55        2.04    scattered clouds
# 2024-11-13 03:00:00        22.26        51        2.54    scattered clouds
# 2024-11-13 06:00:00        27.65        38        4.02          few clouds
# 2024-11-13 09:00:00        30.04        33        2.76           clear sky
# 2024-11-13 12:00:00        27.94        39        1.61           clear sky
# 2024-11-13 15:00:00        24.64        41        1.60          few clouds
# 2024-11-13 18:00:00        22.14        48        1.56          few clouds
# 2024-11-13 21:00:00        21.06        56        1.56    scattered clouds
# ...

# %%
import matplotlib.pyplot as plt

daily_mean_temp = df['Temperature'].resample('D').mean()
daily_mean_humidity = df['Humidity'].resample('D').mean()
daily_mean_wind_speed = df['Wind Speed'].resample('D').mean()

daily_mean_temp
# Out:
# Timestamp
# 2024-11-12    22.326667
# 2024-11-13    24.328750
# 2024-11-14    26.362500
# 2024-11-15    26.545000
# 2024-11-16    26.688750
# 2024-11-17    27.348000
# Freq: D, Name: Temperature, dtype: float64

# %%
plt.figure(figsize=(10, 5))
daily_mean_temp.plot(color="red", linestyle='-')
plt.title("Daily Mean Temperature")
plt.xlabel("Date")
plt.ylabel("Temperature (Celsius)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
daily_mean_humidity.plot(kind="bar", color="blue")
plt.title("Daily Mean Humidity")
plt.xlabel("Date")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Temperature'], df['Humidity'], color='green')
plt.title("Temperature vs Humidity")
plt.xlabel("Temperature (Celsius)")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.show()

# %%
# Define the get_season function
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Add Season column
numeric_df['Season'] = numeric_df.index.month.map(get_season)

# Seasonal Aggregation
seasonal_stats = numeric_df.groupby('Season').mean()

# Filter numeric columns only
numeric_df = df.select_dtypes(include=['number'])

# Aggregate Data
daily_stats = numeric_df.resample('D').mean()
monthly_stats = numeric_df.resample('M').mean()

# Seasonal Aggregation
numeric_df['Season'] = numeric_df.index.month.map(get_season)
seasonal_stats = numeric_df.groupby('Season').mean()

# Print Aggregated Statistics
print("\nMonthly Statistics:\n", monthly_stats)
print("\nSeasonal Statistics:\n", seasonal_stats)

# Print Aggregated Statistics
print("Daily Statistics:\n", daily_stats)
print("\nMonthly Statistics:\n", monthly_stats)
print("\nSeasonal Statistics:\n", seasonal_stats)
# Out:
# Monthly Statistics:
#              Temperature  Humidity  Wind Speed
# Timestamp
# 2024-11-30       25.878     53.55     2.27475
#
# Seasonal Statistics:
#          Temperature  Humidity  Wind Speed
# Season
# Fall         25.878     53.55     2.27475
# Daily Statistics:
#              Temperature   Humidity  Wind Speed
# Timestamp
# 2024-11-12    22.326667  43.666667    1.586667
# 2024-11-13    24.328750  45.125000    2.211250
# 2024-11-14    26.362500  56.250000    2.598750
# 2024-11-15    26.545000  65.000000    2.478750
# 2024-11-16    26.688750  55.125000    1.602500
# 2024-11-17    27.348000  47.800000    3.020000
#
# Monthly Statistics:
#              Temperature  Humidity  Wind Speed
# Timestamp
# 2024-11-30       25.878     53.55     2.27475
#
# Seasonal Statistics:
#          Temperature  Humidity  Wind Speed
# Season
# Fall         25.878     53.55     2.27475

# %%
pip install folium geopandas matplotlib
import folium

# Initialize a map centered on the average latitude and longitude
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
weather_map = folium.Map(location=map_center, zoom_start=2)

# Add markers for each location with temperature info
for _, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['City']}: {row['Temperature']}°C, {row['Humidity']}% Humidity",
        icon=folium.Icon(color='blue' if row['Temperature'] < 20 else 'red')
    ).add_to(weather_map)

# Display map
weather_map
# Out:
#   Cell In[46], line 1
#     pip install folium geopandas matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
# Check the data types of the columns
print(df.dtypes)

# Select only the numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Compute the correlation matrix on the numeric columns
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
# Temperature            float64
# Humidity                 int64
# Wind Speed             float64
# Weather Description     object
# dtype: object
#              Temperature  Humidity  Wind Speed
# Temperature     1.000000 -0.300329    0.339472
# Humidity       -0.300329  1.000000   -0.173227
# Wind Speed      0.339472 -0.173227    1.000000
