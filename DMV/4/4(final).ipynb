# %%
import pandas as pd

# %%
df = pd.read_csv('Real_estate.csv')

# %%
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.columns = [
    'ID',
    'TransactionDate',
    'HouseAge',
    'DistanceToMRT',
    'ConvenienceStores',
    'Latitude',
    'Longitude',
    'UnitPrice'
]

# %%
df.head()
# Out:
#    ID  TransactionDate  HouseAge  DistanceToMRT  ConvenienceStores  Latitude  \
# 0   1         2012.917      32.0       84.87882                 10  24.98298
# 1   2         2012.917      19.5      306.59470                  9  24.98034
# 2   3         2013.583      13.3      561.98450                  5  24.98746
# 3   4         2013.500      13.3      561.98450                  5  24.98746
# 4   5         2012.833       5.0      390.56840                  5  24.97937
#
#    Longitude  UnitPrice
# 0  121.54024       37.9
# 1  121.53951       42.2
# 2  121.54391       47.3
# 3  121.54391       54.8
# 4  121.54245       43.1

# %%
df.isnull().sum()
# Out:
# ID                   0
# TransactionDate      0
# HouseAge             0
# DistanceToMRT        0
# ConvenienceStores    0
# Latitude             0
# Longitude            0
# UnitPrice            0
# dtype: int64

# %%
#Remove rows with missing values
df_dropped = df.dropna()

# %%
# Strategy 2: Impute missing values with median (numerical columns)

df['HouseAge'].fillna(df['HouseAge'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                   0
# TransactionDate      0
# HouseAge             0
# DistanceToMRT        0
# ConvenienceStores    0
# Latitude             0
# Longitude            0
# UnitPrice            0
# dtype: int64

# %%
df_add = pd.read_csv('4_Data.csv')

# %%
df_add
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#Merge
merged_df = pd.merge(df,df_add,on='ID',how = 'left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15864\1956155715.py in ?()
#       1 #Merge
# ----> 2 merged_df = pd.merge(df,df_add,on='ID',how = 'left')
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
#     145     indicator: str | bool = False,
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     733         (
#     734             self.left_join_keys,
# ...

# %%
merged_df = pd.merge(df, df_add, left_on='ID', right_on='area_type', how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 merged_df = pd.merge(df, df_add, left_on='ID', right_on='area_type', how='left')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
# ...

# %%
df = pd.DataFrame({
    'ID': [1, 2, 3, 4, 5],
    'TransactionDate': ['2023-01-01', '2023-03-05', '2023-06-15', '2024-01-10', '2024-02-01'],
    'PropertyType': ['Apartment', 'House', 'House', 'Apartment', 'House'],
    'Location': ['New York', 'San Francisco', 'New York', 'Chicago', 'New York'],
    'Price': [1500, 2500, 2000, 3000, 2200]
})

# %%
# Convert 'TransactionDate' to datetime type for easier filtering
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])

# %%
df['TransactionDate']
# Out:
# 0   2023-01-01
# 1   2023-03-05
# 2   2023-06-15
# 3   2024-01-10
# 4   2024-02-01
# Name: TransactionDate, dtype: datetime64[ns]

# %%
# 2. Filter by property type (e.g., only 'House' type)
filtered_by_type = df[df['PropertyType'] == 'House']
filtered_by_type

# 3. Filter by location (e.g., only properties in 'New York')
filtered_by_location = df[df['Location'] == 'New York']
filtered_by_location
# Out:
#    ID TransactionDate PropertyType  Location  Price
# 0   1      2023-01-01    Apartment  New York   1500
# 2   3      2023-06-15        House  New York   2000
# 4   5      2024-02-01        House  New York   2200

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['PropertyType_encoded'] = label_encoder.fit_transform(df['PropertyType'])

# %%
df
# Out:
#    ID TransactionDate PropertyType       Location  Price  PropertyType_encoded
# 0   1      2023-01-01    Apartment       New York   1500                     0
# 1   2      2023-03-05        House  San Francisco   2500                     1
# 2   3      2023-06-15        House       New York   2000                     1
# 3   4      2024-01-10    Apartment        Chicago   3000                     0
# 4   5      2024-02-01        House       New York   2200                     1

# %%
df['PropertyType_encoded']
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: PropertyType_encoded, dtype: int32

# %%
#Grouping by 'location' (neighborhood) and calculating the average price
avg_price_by_location = df.groupby('Location')['Price'].mean().reset_index()
avg_price_by_location
# Out:
#         Location   Price
# 0        Chicago  3000.0
# 1       New York  1900.0
# 2  San Francisco  2500.0

# %%
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
uppet_bound = Q3 + 1.5 * IQR

# %%
df_no_outliers_price = df[(df['Price'] >= lower_bound) & (df['Price'] <= uppet_bound)]

# %%
df_no_outliers_price
# Out:
#    ID TransactionDate PropertyType       Location  Price  PropertyType_encoded
# 0   1      2023-01-01    Apartment       New York   1500                     0
# 1   2      2023-03-05        House  San Francisco   2500                     1
# 2   3      2023-06-15        House       New York   2000                     1
# 3   4      2024-01-10    Apartment        Chicago   3000                     0
# 4   5      2024-02-01        House       New York   2200                     1

# %%
from scipy.stats import zscore
# 2. Identifying Outliers Using Z-score
df['z_score_price'] = zscore(df['Price'])
df_no_outliers_zscore = df[df['z_score_price'].abs() <= 3]

# Final DataFrame without outliers
final_df = df_no_outliers_price[df_no_outliers_price.index.isin(df_no_outliers_zscore.index)]

# %%
final_df
# Out:
#    ID TransactionDate PropertyType       Location  Price  PropertyType_encoded
# 0   1      2023-01-01    Apartment       New York   1500                     0
# 1   2      2023-03-05        House  San Francisco   2500                     1
# 2   3      2023-06-15        House       New York   2000                     1
# 3   4      2024-01-10    Apartment        Chicago   3000                     0
# 4   5      2024-02-01        House       New York   2200                     1
